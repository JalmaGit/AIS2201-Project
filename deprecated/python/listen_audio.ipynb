# %%
from detection import detection_algorithms as da
from signal_generation import signal_generation as sg
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from IPython.display import Audio

# %%
fs = 48000
signals = sg()

sampling_freq = 48000
time_in_seconds = 6
samples = sampling_freq*time_in_seconds
frequency = 200
Amplitude = 1

pure_tone, time = sg.generate_pure_sinewave(sampling_freq, samples, frequency, Amplitude)
noisy_pure_tone = sg.generate_noisy_signal(pure_tone,1000, Amplitude)

Audio(noisy_pure_tone, rate=sampling_freq)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
harmonic_tone, time = sg.generate_harmonic_sinewave(sampling_freq, samples, frequency, Amplitude)
noisy_harmonic_tone = sg.generate_noisy_signal(harmonic_tone,1000, Amplitude)

Audio(noisy_harmonic_tone, rate=sampling_freq)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fs, farm_noise, time, N = sg.get_sound("data/B_oboe.wav")

Audio(farm_noise, rate=fs)
# Out:
# /home/jalma/Documents/GitHub/AIS2201-Project/python
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
