# %%
from detection import detection_algorithms as da
from signal_generation import signal_generation as sg
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from IPython.display import Audio

# %%
fs = 48000

sampling_freq = 48000
time_in_seconds = 6
samples = sampling_freq*time_in_seconds
frequency = 400
Amplitude = 1

pure_tone, time = sg.generate_pure_sinewave(sampling_freq, samples, frequency, Amplitude)
noisy_pure_tone = sg.generate_noisy_signal(pure_tone,1000, Amplitude*2)
detect = da(fs)

bufferSize = 4096 #Samples in buffer

freq_est = []
time_est = [0]

for index in range(len(noisy_pure_tone)//bufferSize):
    f_est, t = detect.simple_detection(noisy_pure_tone[index*bufferSize:index*bufferSize+bufferSize])

    freq_est.append(f_est)
    time_est.append(t+time_est[-1])

plt.plot(time_est[1:], freq_est)
plt.show()

# %%
freq_est = []
time_est = [0]

bufferSize = 4096 #Samples in buffer
for index in range(len(noisy_pure_tone)//bufferSize):
    X_m, t = detect.increase_spectral_resolution(fs, noisy_pure_tone, time)

    freq_est.append(f_est)
    time_est.append(t+time_est[-1])

print(freq_est)

plt.plot(time_est[1:], freq_est)
plt.show()
# Out:
# [4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375, 4464.84375]
